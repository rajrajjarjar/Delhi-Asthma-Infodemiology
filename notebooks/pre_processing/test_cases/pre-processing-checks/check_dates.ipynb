# %%
import pandas as pd
df = pd.read_csv("E:/Projects/BTP/Data/Clean/Only_cleaned-dates.csv")
print(df['Date'].isna().sum())   # should print 0
print(df['Date'].head())
# Out:
# 0
# 0    2017-06-10
# 1    2017-06-12
# 2    2017-06-13
# 3    2017-06-14
# 4    2017-06-17
# Name: Date, dtype: str

# %%
import pandas as pd
df = pd.read_csv("E:/BTP/Data/Raw_data/Yemen Cholera Outbreak Epidemiology Data - Data_Governorate_Level.csv")
print(df['Date'].isna().sum())   # should print 0
print(df['Date'].head())
# Out:
# 0
# 0    2018-02-18
# 1    2018-02-18
# 2    2018-02-18
# 3    2018-02-18
# 4    2018-02-18
# Name: Date, dtype: str
