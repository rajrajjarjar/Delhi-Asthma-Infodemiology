# %%
import pandas as pd

FILE_PATH = r"E:\BTP\Data\Raw_data\Yemen Cholera Outbreak Epidemiology Data - Data_Governorate_Level.csv"

df = pd.read_csv(FILE_PATH)

unique_names = sorted(df["Governorate"].dropna().unique())

print(f"Total unique governorate names: {len(unique_names)}")
print("\nUnique names:")

for i, name in enumerate(unique_names, start=1):
    print(f"{i}. {name!r}")
# Out:
# Total unique governorate names: 26
#
# Unique names:
# 1. 'AL Mahrah'
# 2. 'Abyan'
# 3. 'Aden'
# 4. 'Al Bayda'
# 5. "Al Dhale'e"
# 6. 'Al Hudaydah'
# 7. 'Al Jawf'
# 8. 'Al Maharah'
# 9. 'Al Mahwit'
# 10. 'Al-Hudaydah'
# 11. 'Al_Jawf'
# 12. 'Amanat Al Asimah'
# 13. 'Amran'
# 14. 'Dhamar'
# 15. 'Hajjah'
# 16. 'Ibb'
# 17. 'Lahj'
# 18. "Ma'areb"
# 19. 'Marib'
# 20. 'Moklla'
# 21. 'Raymah'
# 22. "Sa'ada"
# 23. "Sana'a"
# 24. "Say'on"
# 25. 'Shabwah'
# 26. 'Taizz'

# %%
import pandas as pd

FILE_PATH = r"E:\BTP\Data\Raw_data\Yemen Cholera Outbreak Epidemiology Data - Data_Governorate_Level.csv"

df = pd.read_csv(FILE_PATH)

# Count every exact value in the Governorate column
name_counts = df["Governorate"].value_counts(dropna=False)

print(f"Total rows: {len(df)}")
print(f"Total unique Governorate values: {df['Governorate'].nunique(dropna=False)}")

print("\nGovernorate values and their frequencies:")
print("-" * 60)

for name, count in name_counts.items():
    print(f"{name!r:<35} -> {count} rows")
# Out:
# Total rows: 2914
# Total unique Governorate values: 26
#
# Governorate values and their frequencies:
# ------------------------------------------------------------
# 'Amran'                             -> 136 rows
# 'Al Mahwit'                         -> 136 rows
# "Al Dhale'e"                        -> 136 rows
# 'Hajjah'                            -> 136 rows
# "Sana'a"                            -> 136 rows
# 'Dhamar'                            -> 136 rows
# 'Abyan'                             -> 136 rows
# 'Al Bayda'                          -> 136 rows
# 'Amanat Al Asimah'                  -> 136 rows
# 'Raymah'                            -> 136 rows
# 'Lahj'                              -> 136 rows
# 'Aden'                              -> 136 rows
# 'Ibb'                               -> 136 rows
# 'Taizz'                             -> 136 rows
# "Sa'ada"                            -> 135 rows
# 'Shabwah'                           -> 135 rows
# ...
